# %%
import pandas as pd

# %%
dd = pd.read_csv("../datasets/daraz_dataset.csv")

# %%
# print(dd.head(10))
# print(dd.shape)s
# print(dd.columns)
# print(dd.info())
# print(dd.TotalAmount.max())
# print(dd.TotalAmount.min())
# print(dd.TotalAmount.mean())
# print(dd.CustomerName,dd.District)
# print(dd[["CustomerName","District","TotalAmount"]])
# Out:
#     OrderID   OrderDate  CustomerName  Age Gender   District Category  \
# 0  DZ100001  2026-03-04  Anita Basnet   24   Male  Nepalgunj   Sports
#
#     Product  Quantity  UnitPrice  DiscountPercent  TotalAmount PaymentMethod  \
# 0  Football         1      48898               10      44008.2       IME Pay
#
#    Rating OrderStatus
# 0       1   Delivered

# %%
# print(dd.head(1)) #gives row one
# print(dd.iloc[0]) #takes two major parameters rows(1st one),column
# print(dd.iloc[11]) #takes two major parameters rows(1st one),column
# print(dd.iloc[0,2])#specific cell lai capture garna sakinxa
print(dd.iloc[0,[2]])#specific cell lai capture garna sakinxa
# Out:
# CustomerName    Anita Basnet
# Gender                  Male
# Category              Sports
# Name: 0, dtype: str

# %%
# print(dd.iloc[:,[2,5,8]])# returns all the data in column(2) for all the rows in data
# print(dd.iloc[-1])
# print(dd.loc[:,["CustomerName","District"]])
# Out:
#        CustomerName   District
# 0      Anita Basnet  Nepalgunj
# 1      Pooja Basnet    Pokhara
# 2      Rohit Basnet   Lalitpur
# 3      Pooja Sharma    Chitwan
# 4      Ram Adhikari     Dharan
# ..              ...        ...
# 495      Sita Thapa  Nepalgunj
# 496    Ram Adhikari  Bhaktapur
# 497  Nabin Shrestha    Itahari
# 498   Gita Shrestha     Dharan
# 499  Rohit Adhikari  Bhaktapur
#
# [500 rows x 2 columns]

# %%
# Filtering
# print(dd.loc[dd["District"]=="Kathmandu"])
# print(dd.loc[dd["TotalAmount"]>=30000])

# %%
# print(dd[(dd["District"]=="Kathmandu") & (dd["PaymentMethod"]=="eSewa")])
# Category ="Electronics" & Rating = 5
# print(dd[(dd["Category"]=="Electronics") & (dd["Rating"]==5)])

# %%
# Sorting
print(dd.sort_values("TotalAmount", ascending=False))
# Out:
#       OrderID   OrderDate     CustomerName  Age  Gender    District  \
# 375  DZ100376  2026-02-11       Asha Thapa   18    Male   Bhaktapur
# 271  DZ100272  2026-01-29  Ramesh Adhikari   41    Male     Itahari
# 132  DZ100133  2026-02-04         Sita Rai   52  Female   Bhaktapur
# 435  DZ100436  2026-03-20        Nabin Rai   46    Male      Butwal
# 472  DZ100473  2026-02-22       Sita Karki   42    Male   Kathmandu
# ..        ...         ...              ...  ...     ...         ...
# 94   DZ100095  2026-03-02       Roshan Rai   19    Male  Biratnagar
# 492  DZ100493  2026-05-04     Kiran Sharma   55  Female    Lalitpur
# 74   DZ100075  2026-03-18  Roshan Shrestha   49    Male      Butwal
# 195  DZ100196  2026-05-22    Manish Sharma   19  Female     Chitwan
# 27   DZ100028  2026-02-03     Rohit Basnet   46  Female     Chitwan
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 375        Books           Notebook         5      45982                0
# ...
