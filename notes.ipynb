# %%
# Datatypes in pands
# 1. Series:- one dimensional datatypes.
    # name: manish, anish, nish
# 2. Dataframes:- two dimensional datatypes/ collections of series
    # name: manish, anish, nish
    # age: 23,25,25

#Datasets: Collections of datas available
