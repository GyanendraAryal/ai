# %%
print("Hello World")
# Out:
# Hello World

# %%
print(2+2)
# Out:
# 4

# %%
print(2+2)
print("Bye Bye")
# Out:
# 4
# Bye Bye

# %%
countries = ["Afghanistan", "Albania", "Algeria", "Andorra", "Angola"]
for country in countries:
    print(country)
# Out:
# Afghanistan
# Albania
# Algeria
# Andorra
# Angola
