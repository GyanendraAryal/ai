# %%
import pandas as pd
d=pd.read_csv("../datasets/bad_daraz_dataset.csv")
# print(d)
# print(d.info())

# %%
# d.duplicated().sum() #Number of duplicate items in out datasets

# %%
# d[d.duplicated()]

# %%
# d.duplicated("product_id") :- #checks if the column is unique if not throws duplicated TRUE

# %%
# d.drop_duplicates() #:- Removes the complete duplicate items not partial ones

# %%
# print(d)
# d.drop_duplicates(subset="product_id",inplace=True) #makes the product_id column unique and inplace=True changes the original datasets 
# print(d)

# %%
# print(d)
# d[d["price"]<0]
# d["price"]=pd.to_numeric(d["price"],errors="coerce")
# d["price"].fillna(d["price"].mean())
# d[d["price"]<0]

# %%
# d["price"]

# %%
# d[d["rating"]>5]
# d.loc[d["price"]<0,"price"]=0
# d

# %%
# d["city"]=d["city"].str.strip()
# d["city"].str.rstrip()
# d["city"].str.lstrip()
# d["city"].str.capitalize()
# d["city"].str.lower()
# d["city"].str.upper()
# d["city"].str.title() #first letter upper others small

# %%
#Outliers:testo value jun aru bhanda farak xa legal xa but different(valid)
