# %%
import pandas as pd
d = pd.read_csv("../datasets/bad_daraz_dataset.csv")
# print(d)
# print(d.shape)

# %%
# print(d.isnull())
# d.isnull().count()
# d.isnull().sum() #--> Number of fields Null
# d.fillna(0) #--> missing values ma 0 rakhdinxa
# d["price"].fillna(d["price"].mean())

# %%
# dummy = pd.Series(['100','200','300','400'])
# dummy = pd.Series(['100','def','300','abc'])
# pd.to_numeric(dummy,errors="coerce")

# %%
# d["price"] = pd.to_numeric(d["price"],errors = "coerce")
# d["price"].fillna(d["price"].mean())

# %%
# d["age"]=pd.to_numeric(d["age"],errors ="coerce")
# d["age"].fillna(d["age"].mean())

# %%
# d.dropna() --> Drops all the missing and null values

# %%
# d[d.duplicated()] #--> Better to remove the duplicate data

# %%
# d["discount_percent"].str.replace("%","",regex=True)
