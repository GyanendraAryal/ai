# %%
print("Hello pandas")
# Out:
# Hello pandas

# %%
import pandas as pd
countries = pd.Series(["japan","nepal","usa","india"])
# Out:
#   Cell In[24], line 2
#     pip install openyxl
#         ^
# SyntaxError: invalid syntax

# %%
print(countries)
# Out:
# 0    japan
# 1    nepal
# 2      usa
# 3    india
# dtype: str

# %%
number = pd.Series([10,20,30,40])
print(number)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
number = pd.Series([10,20,30,40],index=["ek","dui","teen","char"])
print(number)
# Out:
# ek      10
# dui     20
# teen    30
# char    40
# dtype: int64

# %%
number_series = pd.Series([10,20,30,40],index=["ek","dui","teen","char"])
pd.Series(number_series.ek)
print(number_series.dui)
print(number_series.teen)
print(number_series.char)
# Out:
# 20
# 30
# 40

# %%
students_data={
    "name":["Manish","Anish","Nish"],
    "age":[24,23,22],
    "course":["ai udan","mern","reactjs"]
}
student_dataframe = pd.DataFrame(students_data)
print(student_dataframe)
# Out:
#      name  age   course
# 0  Manish   24  ai udan
# 1   Anish   23     mern
# 2    Nish   22  reactjs

# %%
datas = pd.read_csv("datasets/student_data.csv")
print(datas)
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
excell_data = pd.read_excel("datasets/excell.xlsx")
print(excell_data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Desktop/Projects/ai/venv/lib/python3.14/site-packages/pandas/compat/_optional.py:158, in import_optional_dependency(name, extra, min_version, errors)
#     157 try:
# --> 158     module = importlib.import_module(name)
#     159 except ImportError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1406, in _gcd_import(name, package, level)
#    1404     if level > 0:
#    1405         name = _resolve_name(name, package, level)
# -> 1406     return _find_and_load(name, _gcd_import)
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
# ...

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
excell_data = pd.read_excel("datasets/excell.xlsx")
print(excell_data)
# Out:
#      Data provided by SimFin  \
# 0                        NaN
# 1    Profit & Loss statement
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 98                       NaN
# 99                       NaN
# 100                      NaN
# 101                      NaN
# 102                      NaN
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                  NaN        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                       in million USD     FY '09     FY '10
# 3                               NET OPERATING REVENUES      30990      35119
# 4                                   Cost of goods sold      11088      12693
# ..                                                 ...        ...        ...
# ...

# %%
emnployees = pd.read_json("datasets/employees.json")
print(emnployees)
# Out:
#    id           name  age   department  salary                email  isActive
# 0   1  Alice Johnson   28           HR   55000    alice@example.com      True
# 1   2      Bob Smith   35  Engineering   85000      bob@example.com      True
# 2   3  Charlie Brown   42      Finance   72000  charlie@example.com     False
# 3   4      David Lee   30    Marketing   63000    david@example.com      True
# 4   5     Emma Davis   27        Sales   60000     emma@example.com      True
